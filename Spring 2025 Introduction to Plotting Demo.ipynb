# %% [markdown]
# # Matplotlib
#
# [Matplotlib](https://matplotlib.org) is a plotting library. The learning objectives of this lecture include
# * Understand what is the matplotlib.pyplot module
# * Apply the module to plot data
#     - Line plot
#     - Bar plot
#     - Scatterplot
#     - Histogram

# %% [markdown]
# ## Install Matplotlib
# If you don't have matplotlib installed, you can issue the below command.  Note that for other libraries such as pandas and numpy, you can also use similar commands to install them in your local system.

# %%
#!conda matplotlib
# !pip install matplotlib

# %% [markdown]
# ## The plot Function

# %%
# SOURCE: https://matplotlib.org/3.1.1/contents.html
import matplotlib.pyplot as plt
# %matplotlib inline

#plt.plot( [1, 2, 2, 4, 5])
plt.plot([4, 1, 0, 2, 3], [1, 2, 2, 4, 5], linestyle="none", marker='^')
plt.ylabel('some numbers')
plt.xlabel('dummy numbers')
plt.show()

# %% [markdown]
# Notice that the x-axis ranges from 0-3 and the y-axis from 1-4. If you provide a single list or array to plot, matplotlib assumes it is a sequence of y values, and automatically generates the x values for you. Since python ranges start with 0, the default x vector has the same length as y but starts with 0. Hence the x data are [0, 1, 2, 3].

# %%
help(plt.show)
# Out:
# Help on function show in module matplotlib.pyplot:
#
# show(close=None, block=None)
#     Display all open figures.
#
#     Parameters
#     ----------
#     block : bool, optional
#         Whether to wait for all figures to be closed before returning.
#
#         If `True` block and run the GUI main loop until all figure windows
#         are closed.
#
#         If `False` ensure that all figure windows are displayed and return
#         immediately.  In this case, you are responsible for ensuring
#         that the event loop is running to have responsive figures.
#
#         Defaults to True in non-interactive mode and to False in interactive
#         mode (see `.pyplot.isinteractive`).
#
#     See Also
#     --------
#     ion : Enable interactive mode, which shows / updates the figure after
#           every plotting command, so that calling ``show()`` is not necessary.
#     ioff : Disable interactive mode.
# ...

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]
plt.figure(1)
plt.xlabel('xlabel here')
plt.ylabel('ylabel here')
plt.title('Title here')
plt.grid(False)
plt.plot(x, y, linewidth=4)
plt.savefig('test1')
plt.show()

# %%
from IPython.core.display import Image
Image(filename='test1.png')
#if you have trouble to run this cell due to the missing png file
#make sure you run the above cell to create the file first

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

plt.figure(1)
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]
plt.plot(x, y, linewidth=5, label='Line 1-1')

plt.figure(2)
plt.title('Figure 2')
z = [2, 8, 18, 32]
plt.plot(x, z, linewidth=1, label='Line 2-1')

plt.figure(2)
plt.plot(x, y, color='red',marker='o', linewidth=1, label='Line 2-2')
#plt.legend()
plt.savefig('Test_fig2')
#plt.close(2)

plt.figure(1)
plt.title("Figure 1")
t = [5, 6, 10, 3]
plt.plot(t, linewidth=8, label='Line 1-2')
plt.legend()
plt.show()

# %% [markdown]
# ## Formatting the style of your plot
# For every x, y pair of arguments, there is an optional third argument which is the format string that indicates the **color** and **line type** of the plot.
#
# * The letters and symbols of the format string are from MATLAB, and you concatenate a color string with a line style string.
# * The default format string is 'b-', which is a solid blue line.
#
# For example, to plot the above with red circles, you would issue

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'r*--')
plt.axis([2, 4, 0, 20])
plt.title('This is a test')
plt.show()

# %% [markdown]
# See the plot documentation for a complete list of line styles and format strings. The **axis** function in the example above takes a list of [xmin, xmax, ymin, ymax] and specifies the viewport of the axes.
#
# ```Python
# plt.axis([0, 6, 0, 20])
# ```
#
# If matplotlib were limited to working with lists, it would be fairly useless for numeric processing. Generally, you will use numpy arrays. In fact, all sequences are converted to numpy arrays internally. The example below illustrates plotting several lines with different format styles in one function call using arrays.

# %%
import numpy as np
x = np.arange(0, 5)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x**2
# Out:
# array([ 0,  1,  4,  9, 16])

# %%
#import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
ps = plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
ps[0].set_label('Line 1')
ps[1].set_label('Line 2')
ps[2].set_label('Line 3')
plt.legend()
plt.xlabel('This is x axis')
plt.ylabel('That is y axis')
plt.title('Three plots')
plt.show()

# %% [markdown]
# ## Plotting with keyword strings
# There are some instances where you have data in a format that lets you access particular variables with strings. For example, with numpy.recarray or pandas.DataFrame.
#
# Matplotlib allows you provide such an object with the data keyword argument. If provided, then you may generate plots with the strings corresponding to these variables.

# %%
import numpy as np
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

#colors = np.random.rand(4)


#plt.scatter('a', 'b', c='c', s='d', data=data)
plt.scatter(data['a'], data['b'],c=data['c'], s=data['d'])

plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [markdown]
# Scatter plots offer a convenient way to visualize how two numeric values are related in your data. It helps in understanding relationships between multiple variables.

# %% [markdown]
# ## Plotting with categorical variables
#
# It is also possible to create a plot using categorical variables. A categorical variable (sometimes called a nominal variable) is one that has two or more categories, but there is no intrinsic ordering to the categories.  For example, gender is a categorical variable having two categories (male and female) and there is no intrinsic ordering to the categories.
#
#
# Matplotlib allows you to pass categorical variables directly to many plotting functions. For example:

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]
#plt.figure(figsize=(12, 3))

plt.title('Categorical Plotting')
plt.ylabel('Number of members')
plt.bar(names, values, color=['b', 'r', 'g'])
plt.savefig('test2')

# %%
help(plt.subplots)
# Out:
# Help on function subplots in module matplotlib.pyplot:
#
# subplots(nrows: 'int' = 1, ncols: 'int' = 1, *, sharex: "bool | Literal['none', 'all', 'row', 'col']" = False, sharey: "bool | Literal['none', 'all', 'row', 'col']" = False, squeeze: 'bool' = True, width_ratios: 'Sequence[float] | None' = None, height_ratios: 'Sequence[float] | None' = None, subplot_kw: 'dict[str, Any] | None' = None, gridspec_kw: 'dict[str, Any] | None' = None, **fig_kw) -> 'tuple[Figure, Any]'
#     Create a figure and a set of subplots.
#
#     This utility wrapper makes it convenient to create common layouts of
#     subplots, including the enclosing figure object, in a single call.
#
#     Parameters
#     ----------
#     nrows, ncols : int, default: 1
#         Number of rows/columns of the subplot grid.
#
#     sharex, sharey : bool or {'none', 'all', 'row', 'col'}, default: False
#         Controls sharing of properties among x (*sharex*) or y (*sharey*)
#         axes:
#
# ...

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

fig, ((ax0, ax1, ax2)) = plt.subplots(1, 3, sharey=True)
plt.setp(fig, figheight=3, figwidth=12)
ax0.bar(names, values, color=['b' ,'r', 'g'])
ax1.scatter(names, values, color=['b' ,'r', 'g'])
ax2.plot(names, values)
plt.setp(ax0, ylabel='Numbers')
plt.suptitle('Categorical Plotting')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
labelnames = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(12, 3))

plt.subplot(131)
#plt.bar(names, values)
plt.bar(names, values, color=['b' ,'r', 'g'], label=labelnames)
plt.legend()
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)

plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# The bar function is able to produce a bar chart that shows the values on the list of values. Each bar presents a name on the list names and the height of each bar presents the corresponding value retrieved from the values list.  For each name on the names list, you may assign a color to present the bar on the bar chart.

# %% [markdown]
# ## Controlling line properties
#
# Lines have many attributes that you can set: linewidth, dash style, antialiased, etc; see matplotlib.lines.Line2D. There are several ways to set line properties

# %% [markdown]
# ### Use keyword args:
# ```Python
# plt.plot(x, y, linewidth=2.0)
# ```

# %% [markdown]
# ### Use the setter methods of a Line2D instance.
# plot returns a list of Line2D objects; e.g., line1, line2 = plot(x1, y1, x2, y2). In the code below we will suppose that we have only one line so that the list returned is of length 1. We use tuple unpacking with line, to get the first element of that list:
# ```Python
# line, = plt.plot(x, y, '-')
# line.set_c('g') # set new color
#
# ```

# %% [markdown]
# ### Use setp.
# The example below uses a MATLAB-style function to set multiple properties on a list of lines. setp works transparently with a list of objects or a single object. You can either use python keyword arguments or MATLAB-style string/value pairs:
# ```Python
# lines = plt.plot(x1, y1, x2, y2)
# # use keyword args
# plt.setp(lines, color='r', linewidth=2.0)
# # or MATLAB style string value pairs
# plt.setp(lines, 'color', 'r', 'linewidth', 2.0)
# ```

# %% [markdown]
# ## Working with multiple figures and axes
# MATLAB, and pyplot, have the concept of the current figure and the current axes. All plotting functions apply to the current axes. The function gca returns the current axes (a matplotlib.axes.Axes instance), and gcf returns the current figure (a matplotlib.figure.Figure instance). Normally, you don't have to worry about this, because it is all taken care of behind the scenes. Below is a script to create two subplots.

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(figsize=(9, 6))

plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')

plt.show()

# %% [markdown]
# A histogram is a plot designed to show the distribution of values in a set of data.   The values are first sorted, and then divided into a fixed number of equal-width bins.  A plot is then drawn that shows the number of elements in each bin.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
plt.hist(x, 10, density=False, facecolor='b', alpha=0.3)
# Out:
# (array([  14.,   96.,  491., 1420., 2597., 2804., 1788.,  619.,  141.,
#           30.]),
#  array([ 42.80526189,  53.96138881,  65.11751572,  76.27364264,
#          87.42976955,  98.58589647, 109.74202338, 120.8981503 ,
#         132.05427721, 143.21040413, 154.36653104]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 10, density=False, facecolor='b', alpha=0.25)

plt.xlabel('Smarts')
plt.ylabel('Frequency Numbers')
#plt.ylabel('Probablity density')
plt.title('Histogram of IQ')
plt.text(60, 550, r'$\mu=100,\ \sigma=15$')
#plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
# %matplotlib inline
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)
y = [random.randrange(40, 160) for i in range(10000)]

# the histogram of the data

colors = ['lime', 'tan']
#plt.hist([x, y], 20, color=colors)
plt.hist([x, y], 50, histtype="bar", color=colors, fill=True, stacked=False)

plt.show()

# %%
np.random.seed(0)

n_bins = 10
x = np.random.randn(1000, 3)


fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(9, 8))

ax0, ax1, ax2, ax3 = axes.flatten()

colors = ['lightblue', 'tan', 'limegreen']

ax0.hist(x, n_bins, density=True, histtype='bar', color=colors, label=["First", "Second", "Third"])
ax0.legend(prop={'size': 10})
ax0.set_title('bars with legend')

ax1.hist(x, n_bins, density=True, histtype='bar', color=colors, stacked=True)
ax1.set_title('stacked bar')

ax2.hist(x, n_bins, histtype='step', stacked=True, fill=False)
ax2.set_title('stack step (unfilled)')

# Make a multiple-histogram of data-sets with different length.
x_multi = np.array([np.random.randn(n) for n in [10000, 5000, 2000]], dtype=object)

ax3.hist(x_multi, n_bins, histtype='bar', color=colors)
ax3.set_title('different sample sizes')

plt.savefig('test3')

plt.show()

# %%
from IPython.core.display import Image
Image(filename='test3.png')

# %% [markdown]
# ## Annotating text
#  A common use for text is to annotate some feature of the plot, and the annotate method provides helper functionality to make annotations easy. In an annotation, there are two points to consider: the location being annotated represented by the argument xy and the location of the text xytext. Both of these arguments are (x, y) tuples.

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# In this basic example, both the xy (arrow tip) and xytext locations (text location) are in data coordinates. There are a variety of other coordinate systems one can choose

# %% [markdown]
# * https://matplotlib.org/tutorials/introductory/pyplot.html
# * Chapter 13 Plotting and more about classes, Introduction to Computation and Programming Using Python, Third edition by John V Guttag
